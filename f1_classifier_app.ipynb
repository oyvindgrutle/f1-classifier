# %%
# %config Completer.use_jedi = False
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Config option `use_jedi` not recognized by `IPCompleter`.
#   """Entry point for launching an IPython kernel.

# %%
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
from fastbook import *

# %%
# %matplotlib inline
from fastai.vision.all import *

# %%
DATA = Path('/content/gdrive/MyDrive/DAT255/formula1-classifier')

# %%
(DATA).ls()
# Out:
# (#4) [Path('/content/gdrive/MyDrive/DAT255/formula1-classifier/formula-one-cars.zip'),Path('/content/gdrive/MyDrive/DAT255/formula1-classifier/Formula One Cars'),Path('/content/gdrive/MyDrive/DAT255/formula1-classifier/models'),Path('/content/gdrive/MyDrive/DAT255/formula1-classifier/images')]

# %%
MODELS = DATA/'models'

# %%
MODELS.ls()
# Out:
# (#2) [Path('/content/gdrive/MyDrive/DAT255/formula1-classifier/models/f1_classifier_v1'),Path('/content/gdrive/MyDrive/DAT255/formula1-classifier/models/f1_classifier_v2')]

# %%
learn = load_learner(MODELS/'f1_classifier_v2')

# %%
import ipywidgets as widgets

# %%
uploader = widgets.FileUpload()
uploader
# Out:
# FileUpload(value={}, description='Upload')

# %%
img = PILImage.create(uploader.data[0])

# %%
img.shape
# Out:
# (561, 997)

# %%
img
# Out:
# PILImage mode=RGB size=997x561

# %%
pred,_,probs = learn.predict(img)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
pred
# Out:
# 'Red Bull Racing F1 car'

# %%
probs.max()
# Out:
# TensorBase(0.8936)
